# %% [markdown]
# # TP Organización Empresarial - Google Colab
#
# Este notebook sirve para mostrar que el proyecto se puede ejecutar desde Google Colab.

# %% [markdown]
# ## 1. Configurar identidad de Git
#
# Cambiar el email si querés usar otro. Esto sirve para que los commits queden con tu nombre.

# %%
# !git config --global user.name "Leandro Nicolas Acuña"
# !git config --global user.email "88015691+Leanmucho@users.noreply.github.com"

# %% [markdown]
# ## 2. Clonar el repositorio
#
# Si la carpeta ya existe en Colab, primero la borro para clonar una versión limpia.

# %%
# !rm -rf TP-2-Gesti-n-Colaborativa-Control-de-Versiones-y-Organizaci-n-Empresarial
# !git clone https://github.com/Leanmucho/TP-2-Gesti-n-Colaborativa-Control-de-Versiones-y-Organizaci-n-Empresarial.git

# %% [markdown]
# ## 3. Entrar al proyecto y revisar archivos

# %%
# %cd TP-2-Gesti-n-Colaborativa-Control-de-Versiones-y-Organizaci-n-Empresarial
# !ls
# !ls datos scripts resultados

# %% [markdown]
# ## 4. Ejecutar el análisis climático
#
# El script usa rutas relativas, por eso funciona igual en Colab y en una computadora local.

# %%
# !python scripts/analisis_clima.py

# %% [markdown]
# ## 5. Ver resultados generados

# %%
# !cat resultados/resumen_clima.csv
from IPython.display import Image, display
display(Image(filename='resultados/grafico_temperatura_buenos_aires.png'))

# %% [markdown]
# ## 6. Si necesitás hacer push desde Colab
#
# No pegues el token directo en una celda visible. Usá `getpass`, así no queda escrito en el notebook.

# %%
from getpass import getpass

token = getpass('Pegá tu PAT de GitHub (no se va a mostrar): ')
user = 'Leanmucho'
repo = 'TP-2-Gesti-n-Colaborativa-Control-de-Versiones-y-Organizaci-n-Empresarial'

# Ejemplo de push seguro. Ejecutarlo solo si realmente hiciste cambios en Colab.
# !git push https://{token}@github.com/{user}/{repo}.git feature/analisis-clima
print('Token cargado en memoria. No quedó escrito en el notebook.')
